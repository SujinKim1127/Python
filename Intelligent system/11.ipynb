# %% [markdown]
# ## 문제 2
# 아래에 명시된 조건을 만족하는 data와 prediction 값을 생성하여 [실행예시] 가 올바르게 실행됨을 보이시오.
# X : 0과 3 사이의 랜덤값으로 이루어진 50개의 데이터
# theta0 : 2
# theta1 : 3![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

X = 3*np.random.rand(50,1)
y = 2 + 3*X + np.random.randn(50,1)
theta0 = 2
theta1 = 3
N = 50
theta = np.array([[theta1, theta0]]).T
oneColumns = np.full((N,1),1)
print(oneColumns.shape)
X1 = np.column_stack((X,oneColumns)) 
predictions = np.matmul(X1, theta)

plt.scatter(X,y)
print("X.shape: ", X.shape)
print("y.shape: ", y.shape)
print("max(X): ", max(X))
print("min(X): ", min(X))
print("theta: ", theta)
print("X1,shape: ", X1.shape)
print("predictions[:3]: ", predictions[:3])
print("predictions.shape: ", predictions.shape)
# Out:
# (50, 1)
# X.shape:  (50, 1)
# y.shape:  (50, 1)
# max(X):  [2.9244092]
# min(X):  [0.125433]
# theta:  [[3]
#  [2]]
# X1,shape:  (50, 2)
# predictions[:3]:  [[ 9.51350603]
#  [ 5.70616671]
#  [10.32625073]]
# predictions.shape:  (50, 1)
