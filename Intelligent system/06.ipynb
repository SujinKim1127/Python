# %% [markdown]
# ## 문제1
# 다음 결과가 출력 될 수 있도록 빈칸을 채우시오
# ![image.png](attachment:image.png)

# %%
def about_defining_function():
    print("This is how to defining function")
    
print("This is your first function")

about_defining_function()
# Out:
# This is your first function
# This is how to defining function

# %% [markdown]
# ## 문제2
# 다음 결과가 출력 될 수 있도록 special_menu_price 함수를 작성하시오.
# ![image-2.png](attachment:image-2.png)

# %%
def special_menu_price(menu="beaf",price=100):
    print("Today special menu is " + menu + ".")
    print("The price of " + menu + " is " + str(price) + " dollar")
    print("enjoy!\n")
    
special_menu_price(price=200)
special_menu_price("lamb")
# Out:
# Today special menu is beaf.
# The price of beaf is 200 dollar
# enjoy!
#
# Today special menu is lamb.
# The price of lamb is 100 dollar
# enjoy!

# %% [markdown]
# ## 문제3
# 에러 발생하지 않도록 코드 수정하기
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 문제4
# square_cube는 주어진 arguments의 앞의 절반은 각각 제곱을 하고 뒤의 절반은 세제곱 하는 함수이다.
# numbers를 arguments로 받을 때 다음 결과가 출력 될 수 있도록 빈칸을 채우시오.
# (단, *arguments를 사용하고 함수 안의 square, cube 변수는 List Comprehension 사용하여 빈칸을 채우시오)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 문제5
# 다음 결과가 출력 될 수 있도록 add_mul_sub 함수를 작성하시오
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 문제6
# 다음 함수는 keyword argument를 활용한 함수이다. 다음 결과가 출력 될 수 있도록 빈칸을 채우시오.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 문제7
# ![image.png](attachment:image.png)
# 7-1)위 코드에서 에러가 발생하지 않도록 코드를 고쳐서 작성하고, 출력 결과를 보이시오.

# %% [markdown]
# 7-2)위 코드가 에러인 이유에 대해서 print문으로 출력하시오.

# %% [markdown]
# ## 문제8
# ![image.png](attachment:image.png)
# pi=3.14를 class variable로 갖고 instance 생성시 radius를  받아 __init__ 메소드를 사용하여 원의 둘레인 Circumference를 instance variable로 갖도록 하는 Circle 클래스를 작성하고 위와 같이 출력 결과를 보이시오.(반지름은 자기 학번의 앞 두 자리로 사용)
