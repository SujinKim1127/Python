# %% [markdown]
# #### 문제1
# 다음 코드는 Cost를 구하는 코드이다. 아래 Cost 계산식을 참고하여 빈칸을 채우시오.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제2
# 다음 코드는 parameter를 update 하는 코드이다. 아래 parameter update 계산식을 참고하여 빈칸을 채우시오.![image-2.png](attachment:image-2.png)
